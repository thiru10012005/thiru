# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("d:/Users/Student/Downloads/dataset/dataset/tvmarketing.csv")
df.head()
# Out:
#    Advertisments  Sales
# 0          230.1   22.1
# 1           44.5   10.4
# 2           17.2    9.3
# 3          151.5   18.5
# 4          180.8   12.9

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("d:/Users/Student/Downloads/dataset/dataset/tvmarketing.csv")
df.head()
x=df.Advertisments
y=df.Sales
plt.scatter(x,y)
sns.heatmap(df.corr(),annot=True)
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import pickle
x_train,x_test,y_train,y_test=train_test_split(df[['Advertisments']],df['Sales'],test_size=0.3,random_state=109)
linearRegr=LinearRegression()
linearRegr.fit(x_train,y_train)
y_pred=linearRegr.predict(x_test)

# %%
c
